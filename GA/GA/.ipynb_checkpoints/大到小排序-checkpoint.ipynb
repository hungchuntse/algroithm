# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import functools
import operator
import random

df_week1=pd.read_csv("C:\\Users\\user\\Desktop\\week1.csv",encoding="big5")
df_week2=pd.read_csv("C:\\Users\\user\\Desktop\\week2.csv",encoding="big5")
df_week3=pd.read_csv("C:\\Users\\user\\Desktop\\week3.csv",encoding="big5")
df_week4=pd.read_csv("C:\\Users\\user\\Desktop\\week4.csv",encoding="big5")
week1=df_week1.values.tolist()
week2=df_week2.values.tolist()
week3=df_week3.values.tolist()
week4=df_week4.values.tolist()

class final_project():
    def __init__(self,count2,count3,count4,total_1,total_2,total_3,total_4, List_1,List_2,List_3,List_4, week1_1,week2_1,week3_1,week4_1, month_1,month_2,month_3,month_4, t_week_1,t_week_2,t_week_3,t_week_4, t_month_1,t_month_2,t_month_3,t_month_4,batch,total_month,count,tls,total_tls,week_a,week_ac,week_as):
        self.total_1 = total_1
        self.total_2 = total_2
        self.total_3 = total_3
        self.total_4 = total_4
        
        self.List_1 = List_1
        self.List_2 = List_2
        self.List_3 = List_3
        self.List_4 = List_4
        
        self.week1_1 = week1_1
        self.week2_1 = week2_1
        self.week3_1 = week3_1
        self.week4_1 = week4_1
        
        self.month_1 = month_1
        self.month_2 = month_2
        self.month_3 = month_3
        self.month_4 = month_4
        
        self.t_week_1 = t_week_1
        self.t_week_2 = t_week_2
        self.t_week_3 = t_week_3
        self.t_week_4 = t_week_4
        
        self.t_month_1 = t_month_1
        self.t_month_2 = t_month_2
        self.t_month_3 = t_month_3
        self.t_month_4 = t_month_4
        
        self.total_month=total_month
        self.batch=batch
        
        self.tls=tls
        self.total_tls=total_tls
     
        self.count=count
        self.count2=count2
        self.count3=count3
        self.count4=count4
        
        self.week_a=week_a
        self.week_as=week_as
        self.week_ac=week_ac
    
    def classification_1(self):
        for gen1 in range(70, 80):
            low1 = gen1
            for j in range(21):
                for i in range(len(week1)):
                    if int(week1[i][0] / 10000) == low1:
                        self.List_1.append(week1[i])
                        #print(cords[i])
                low1 += 1
            self.total_1.append(self.List_1)
            self.List_1 = []
            
    def classification_2(self):
        for gen2 in range(70, 80):
            low2 = gen2
            for j in range(21):
                for i in range(len(week2)):
                    if int(week2[i][0] / 10000) == low2:
                        self.List_2.append(week2[i])
                        #print(cords[i])
                low2 += 1
            self.total_2.append(self.List_2)
            self.List_2 = []
            
    def classification_3(self):
        for gen3 in range(70, 80):
            low3 = gen3
            for j in range(21):
                for i in range(len(week3)):
                    if int(week3[i][0] / 10000) == low3:
                        self.List_3.append(week3[i])
                        #print(cords[i])
                low3 += 1
            self.total_3.append(self.List_3)
            self.List_3 = []
    
    def classification_4(self):
        for gen4 in range(70, 80):
            low4 = gen4
            for j in range(21):
                for i in range(len(week4)):
                    if int(week4[i][0] / 10000) == low4:
                        self.List_4.append(week4[i])
                        #print(cords[i])
                low4 += 1
            self.total_4.append(self.List_4)
            self.List_4 = []

    def classification_5(self, total_1):
        for i in range(len(self.total_1)):
            for j in range(len(self.total_1[i])):
                cal1 = self.total_1[i][j][0] % 100
                if cal1 == 68 or cal1 == 42 or cal1 == 0:
                    self.week1_1.append(self.total_1[i][j])
                else:
                    self.month_1.append(self.total_1[i][j])
            
            self.t_week_1.append(self.week1_1)
            self.t_month_1.append(self.month_1)
            self.week1_1 = []
            self.month_1 = []
            
    def classification_6(self, total_2):
        for i in range(len(self.total_2)):
            for j in range(len(self.total_2[i])):
                cal2 = self.total_2[i][j][0] % 100
                if cal2 == 68 or cal2 == 42 or cal2 == 0:
                    self.week2_1.append(self.total_2[i][j])
                else:
                    self.month_2.append(self.total_2[i][j])
            
            self.t_week_2.append(self.week2_1)
            self.t_month_2.append(self.month_2)
            self.week2_1 = []
            self.month_2 = []
            
            
            
    def classification_7(self, total_3):
        for i in range(len(self.total_3)):
            for j in range(len(self.total_3[i])):
                cal3 = self.total_3[i][j][0] % 100
                if cal3 == 68 or cal3 == 42 or cal3 == 0:
                    self.week3_1.append(self.total_3[i][j])
                else:
                    self.month_3.append(self.total_3[i][j])
            
            self.t_week_3.append(self.week3_1)
            self.t_month_3.append(self.month_3)
            self.week3_1 = []
            self.month_3 = []
    
    def classification_8(self, total_4):
        for i in range(len(self.total_4)):
            for j in range(len(self.total_4[i])):
                cal4 = self.total_4[i][j][0] % 100
                if cal4 == 68 or cal4 == 42 or cal4 == 0:
                    self.week4_1.append(self.total_4[i][j])
                else:
                    self.month_4.append(self.total_4[i][j])
            
            self.t_week_4.append(self.week4_1)
            self.t_month_4.append(self.month_4)
            self.week4_1 = []
            self.month_4 = []
            

    def sort(self):
        for i in range(len(self.t_month_1)):
            self.t_month_1[i] = sorted(self.t_month_1[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_month_2)):
            self.t_month_2[i] = sorted(self.t_month_2[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_month_3)):
            self.t_month_3[i] = sorted(self.t_month_3[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_month_4)):
            self.t_month_4[i] = sorted(self.t_month_4[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_week_1)):
            self.t_week_1[i] = sorted(self.t_week_1[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_week_2)):
            self.t_week_2[i] = sorted(self.t_week_2[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_week_3)):
            self.t_week_3[i] = sorted(self.t_week_3[i], key=lambda x: x[1], reverse=True)
        for i in range(len(self.t_week_4)):
            self.t_week_4[i] = sorted(self.t_week_4[i], key=lambda x: x[1], reverse=True)
            
        print(self.t_month_1)
        print("--------------------------------------------------------------------------")
        print(self.t_month_2)
        print("--------------------------------------------------------------------------")
        print(self.t_month_3)
        print("--------------------------------------------------------------------------")
        print(self.t_month_4)
        print("--------------------------------------------------------------------------")
        print(self.t_week_1)
        print("--------------------------------------------------------------------------")
        print(self.t_week_2)
        print("--------------------------------------------------------------------------")
        print(self.t_week_3)
        print("--------------------------------------------------------------------------")
        print(self.t_week_4)
    
    def batch1(self,t_week_1,t_month_1):
        self.tls=0
        self.total_tls=[]
        
        self.count=[]
        self.count.append(self.t_week_1)
        self.count.append(self.t_month_1)
        for k in range(5):
            for i in range (len(self.count)):
                for l in range(len(self.count[i])):
                    for j in range(len(self.count[i][l])):
                        self.tls=self.tls+self.count[i][l][j][1]

                        if self.tls<=672:
                            e=l
                            while e <len(self.count[i])-1:
                                e=e+1


                                for m in range(len(self.count[i][e])):
                                    if self.count[i][l][j][2] == self.count[i][e][m][2]:
                                        self.count[i][e][m][0]=0
                                        self.count[i][e][m][1]=0
                                        self.count[i][e][m][2]=0
                                        self.count[i][e][m][3]=0

                            
                            self.count[i][l][j][0]=0
                            self.count[i][l][j][1]=0
                            self.count[i][l][j][2]=0
                            self.count[i][l][j][3]=0

                        if self.tls>672:
                            self.tls=self.tls-self.count[i][l][j][1]
                            lb=672-self.tls
                            if lb>=23 and self.count[i][l][j][1]-lb>=23:

                                self.count[i][l][j][1]=self.count[i][l][j][1]-lb
                                self.tls=self.tls+lb
                            

            self.total_tls.append(self.tls)
            self.tls=0

        print("batch1",self.total_tls)
        print("----------------------")
        print(self.count)
        print("----------------------")
        print(self.count[0])
        print("----------------------")
        print(self.count[1])
        print("----------------------")
    
    def batch1_result(self,count):
        self.week_a=[]
        self.week_as=0
        self.week_ac=0
        
        for i in range(len(self.count)):
            for l in range(len(self.count[i])):
                for j in range(len(self.count[i][l])):
                    
                    

                                
                                
                    if self.count[i][l][j][3] !=0:                
                        self.week_a.append(self.count[i][l][j])
                        self.count[i][l][j][3]=0
                        self.week_as=self.week_as+self.count[i][l][j][1]
                        
                    
        for k in range(len(self.week_a)):
            self.week_a[k][3]=1                
        print('剩餘',self.week_a)
        print('剩餘數',self.week_as)

        self.week_ac=len(self.week_a)
        print(self.week_ac)
    
    def batch2(self,t_week_2,t_month_2,count):
        self.tls=0
        self.total_tls=[]
        
        self.count2=[]
        
        self.count2.append(self.t_week_2)
        self.count2.append(self.count[1])
        self.count2.append(self.t_month_2)
        for k in range(5):
            for i in range (len(self.count2)):
                for l in range(len(self.count2[i])):
                    for j in range(len(self.count2[i][l])):
                        self.tls=self.tls+self.count2[i][l][j][1]

                        if self.tls<=672:
                            e=l
                            while e <len(self.count2[i])-1:
                                e=e+1


                                for m in range(len(self.count2[i][e])):
                                    if self.count2[i][l][j][2] == self.count2[i][e][m][2] :
                                        self.count2[i][e][m][0]=0
                                        self.count2[i][e][m][1]=0
                                        self.count2[i][e][m][2]=0
                                        self.count2[i][e][m][3]=0

                            
                            self.count2[i][l][j][0]=0
                            self.count2[i][l][j][1]=0
                            self.count2[i][l][j][2]=0
                            self.count2[i][l][j][3]=0

                        if self.tls>672:
                            self.tls=self.tls-self.count2[i][l][j][1]
                            lb=672-self.tls
                            if lb>=23 and self.count2[i][l][j][1]-lb>=23:

                                self.count2[i][l][j][1]=self.count2[i][l][j][1]-lb
                                self.tls=self.tls+lb
    
                    
            self.total_tls.append(self.tls)
            self.tls=0

        print("batch2",self.total_tls)
        print("----------------------")
        print(self.count2)
        print("----------------------")
        print(self.count2[0])
        print("----------------------")
        print(self.count2[1])
        print("----------------------")
        print(self.count2[2])
        print("----------------------")

        
    def batch2_result(self,count2):
        self.week_a=[]
        self.week_as=0
        self.week_ac=0
        
        for i in range(len(self.count2)):
            for l in range(len(self.count2[i])):
                for j in range(len(self.count2[i][l])):
                    
                    

                                
                                
                    if self.count2[i][l][j][3] !=0:                
                        self.week_a.append(self.count2[i][l][j])
                        self.count2[i][l][j][3]=0
                        self.week_as=self.week_as+self.count2[i][l][j][1]
                        
                    
        for k in range(len(self.week_a)):
            self.week_a[k][3]=1                
        print('剩餘',self.week_a)
        print('剩餘數',self.week_as)

        self.week_ac=len(self.week_a)
        print(self.week_ac)
    
    def batch3(self,t_week_3,t_month_3,count2):
        self.tls=0
        self.total_tls=[]
        
        self.count3=[]
        
        self.count3.append(self.t_week_3)
        self.count3.append(self.count2[2])
        self.count3.append(self.t_month_3)
        for k in range(5):
            for i in range (len(self.count3)):
                for l in range(len(self.count3[i])):
                    for j in range(len(self.count3[i][l])):
                        self.tls=self.tls+self.count3[i][l][j][1]

                        if self.tls<=672:
                            e=l
                            while e <len(self.count3[i])-1:
                                e=e+1


                                for m in range(len(self.count3[i][e])):
                                    if self.count3[i][l][j][2] == self.count3[i][e][m][2]:
                                        self.count3[i][e][m][0]=0
                                        self.count3[i][e][m][1]=0
                                        self.count3[i][e][m][2]=0
                                        self.count3[i][e][m][3]=0

                            
                            self.count3[i][l][j][0]=0
                            self.count3[i][l][j][1]=0
                            self.count3[i][l][j][2]=0
                            self.count3[i][l][j][3]=0

                        if self.tls>672:
                            self.tls=self.tls-self.count3[i][l][j][1]
                            lb=672-self.tls
                            if lb>=23 and self.count3[i][l][j][1]-lb>=23:

                                self.count3[i][l][j][1]=self.count3[i][l][j][1]-lb
                                self.tls=self.tls+lb
    

            self.total_tls.append(self.tls)
            self.tls=0

        print("batch3",self.total_tls)
        print("----------------------")
        print(self.count3)
        print("----------------------")
        print(self.count3[0])
        print("----------------------")
        print(self.count3[1])
        print("----------------------")
        print(self.count3[2])
        print("----------------------")

        
    def batch3_result(self,count3):
        self.week_a=[]
        self.week_as=0
        self.week_ac=0
        
        for i in range(len(self.count3)):
            for l in range(len(self.count3[i])):
                for j in range(len(self.count3[i][l])):
                    
                    

                                
                                
                    if self.count3[i][l][j][3] !=0:                
                        self.week_a.append(self.count3[i][l][j])
                        self.count3[i][l][j][3]=0
                        self.week_as=self.week_as+self.count3[i][l][j][1]
                        
                    
        for k in range(len(self.week_a)):
            self.week_a[k][3]=1                
        print('剩餘',self.week_a)
        print('剩餘數',self.week_as)

        self.week_ac=len(self.week_a)
        print(self.week_ac)
        
    def batch4(self,t_week_4,t_month_4,count3):
        self.tls=0
        self.total_tls=[]
        
        self.count4=[]
        
        self.count4.append(self.t_week_4)
        self.count4.append(self.count3[2])
        self.count4.append(self.t_month_4)
        for k in range(5):
            for i in range (len(self.count4)):
                for l in range(len(self.count4[i])):
                    for j in range(len(self.count4[i][l])):
                        self.tls=self.tls+self.count4[i][l][j][1]

                        if self.tls<=672:
                            e=l
                            while e <len(self.count4[i])-1:
                                e=e+1


                                for m in range(len(self.count3[i][e])):
                                    if self.count4[i][l][j][2] == self.count4[i][e][m][2] :
                                        self.count4[i][e][m][0]=0
                                        self.count4[i][e][m][1]=0
                                        self.count4[i][e][m][2]=0
                                        self.count4[i][e][m][3]=0

                            
                            self.count4[i][l][j][0]=0
                            self.count4[i][l][j][1]=0
                            self.count4[i][l][j][2]=0
                            self.count4[i][l][j][3]=0

                        if self.tls>672:
                            self.tls=self.tls-self.count4[i][l][j][1]
                            lb=672-self.tls
                            if lb>=23 and self.count4[i][l][j][1]-lb>=23:
                                
                                self.count4[i][l][j][1]=self.count4[i][l][j][1]-lb
                                self.tls=self.tls+lb
    

            self.total_tls.append(self.tls)
            self.tls=0

        print("batch4",self.total_tls)
        print("----------------------")
        print(self.count4)
        print("----------------------")
        print(self.count4[0])
        print("----------------------")
        print(self.count4[1])
        print("----------------------")
        print(self.count4[2])
        print("----------------------")
        

    def batch4_result(self,count4):
        self.week_a=[]
        self.week_as=0
        self.week_ac=0
        
        for i in range(len(self.count4)):
            for l in range(len(self.count4[i])):
                for j in range(len(self.count4[i][l])):
                    
                    

                                
                                
                    if self.count4[i][l][j][3] !=0:                
                        self.week_a.append(self.count4[i][l][j])
                        self.count4[i][l][j][3]=0
                        self.week_as=self.week_as+self.count4[i][l][j][1]
                        
                    
        for k in range(len(self.week_a)):
            self.week_a[k][3]=1
            
        print('剩餘',self.week_a)
        print('剩餘數',self.week_as)

        self.week_ac=len(self.week_a)
        print(self.week_ac)
            
    def main(self):
        self.classification_1()
        self.classification_2()
        self.classification_3()
        self.classification_4()
        self.classification_5(self.total_1)
        self.classification_6(self.total_2)
        self.classification_7(self.total_3)
        self.classification_8(self.total_4)
        self.sort()
        self.batch1(self.t_month_1,self.t_week_1)
        self.batch1_result(self.count)
        self.batch2(self.t_month_2,self.t_week_2,self.count)
        self.batch2_result(self.count2)
        self.batch3(self.t_month_3,self.t_week_3,self.count2)
        self.batch3_result(self.count3)
        self.batch4(self.t_month_4,self.t_week_4,self.count3)
        self.batch4_result(self.count4)

if __name__ =="__main__":
    fin = final_project([], [], [], [], [], [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[])
    fin.main()
# Out:
# [[[866290, 149, 147, 1], [716290, 148, 169, 1], [716290, 134, 168, 1], [716290, 133, 161, 1], [713290, 132, 179, 1], [756891, 130, 143, 1], [716290, 128, 167, 1], [713290, 117, 177, 1], [716290, 114, 157, 1], [716391, 109, 164, 1], [716290, 102, 155, 1], [860290, 86, 145, 1], [906290, 83, 150, 1], [723290, 82, 141, 1], [716391, 80, 165, 1], [716391, 77, 156, 1], [863290, 71, 146, 1], [716391, 70, 170, 1], [716290, 69, 160, 1], [716290, 63, 172, 1], [713290, 61, 173, 1], [726290, 61, 142, 1], [706391, 60, 140, 1], [716290, 60, 159, 1], [716290, 58, 180, 1], [716391, 53, 171, 1], [716290, 51, 153, 1], [903290, 50, 149, 1], [716290, 45, 178, 1], [706290, 40, 163, 1], [886290, 24, 148, 1]], [[866290, 149, 147, 1], [716290, 148, 169, 1], [716290, 134, 168, 1], [716290, 133, 161, 1], [713290, 132, 179, 1], [756891, 130, 143, 1], [716290, 128, 167, 1], [713290, 117, 177, 1], [716290, 114, 157, 1], [716391, 109, 164, 1], [716290, 102, 155, 1], [860290, 86, 145, 1], [906290, 83, 150, 1], [723
# ...
